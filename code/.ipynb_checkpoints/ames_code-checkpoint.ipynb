# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px" />
#
# # proyect 2  Ames Iowa!
#
# ----

# %% [markdown]
# ## Problem statement:

# %% [markdown]
# #### My research aims to describe several factors that may affect the price of  houses in Ames Iowa. I specifically focus on which towns in Ames had the highest sales rate between 2006-2010. The findings will be represented in a table with information about the model of linear regression to try to predict home values.

# %% [markdown]
# ## Data descreption:
#
# Description of the data [data description](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt).

# %% [markdown]
# ## Agenda:
# ---
#
# #### 1. Libraries
# #### 2. Data import and cleaning
# #### 3. Visualization
# #### 4. Data analysis
# #### 5. Feature engineering
# #### 6. Feature engineering
# #### 7. Creating models
# #### 8. Conclusions

# %% [markdown]
# ## 1. Libraries:
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno
import matplotlib.pyplot as plt

from sklearn.preprocessing import OrdinalEncoder,StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## 2. Data Import and Cleaning:
# ---

# %%
#import datasets from the folder

pd.set_option('display.max_columns', None) # to see all the columns on my dataframe
train = pd.read_csv('../datasets/train.csv')
test = pd.read_csv('../datasets/test.csv')
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
# TRAINING
# Checking for null values
null_columns = train.columns[train.isnull().any()]#https://dzone.com/articles/pandas-find-rows-where-columnfield-is-null
train[null_columns].isnull().sum()
# Out:
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %%
# TESTING
# Checking for null values
null_colum = test.columns[test.isnull().any()]#https://dzone.com/articles/pandas-find-rows-where-columnfield-is-null
test[null_colum].isnull().sum()
# Out:
# Lot Frontage      160
# Alley             820
# Mas Vnr Type        1
# Mas Vnr Area        1
# Bsmt Qual          25
# Bsmt Cond          25
# Bsmt Exposure      25
# BsmtFin Type 1     25
# BsmtFin Type 2     25
# Electrical          1
# Fireplace Qu      422
# Garage Type        44
# Garage Yr Blt      45
# Garage Finish      45
# Garage Qual        45
# Garage Cond        45
# Pool QC           874
# Fence             706
# Misc Feature      837
# dtype: int64

# %%
# Graphic null with the missingno library 
missingno.matrix(train,figsize = (20,6));

# %%
train.shape
# Out:
# (2051, 81)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
#  16  Bldg Type        2051 non-null   object
#  17  House Style      2051 non-null   object
#  18  Overall Qual     2051 non-null   int64
#  19  Overall Cond     2051 non-null   int64
#  20  Year Built       2051 non-null   int64
#  21  Year Remod/Add   2051 non-null   int64
#  22  Roof Style       2051 non-null   object
#  23  Roof Matl        2051 non-null   object
#  24  Exterior 1st     2051 non-null   object
#  25  Exterior 2nd     2051 non-null   object
#  26  Mas Vnr Type     2029 non-null   object
#  27  Mas Vnr Area     2029 non-null   float64
#  28  Exter Qual       2051 non-null   object
#  29  Exter Cond       2051 non-null   object
#  30  Foundation       2051 non-null   object
#  31  Bsmt Qual        1996 non-null   object
#  32  Bsmt Cond        1996 non-null   object
#  33  Bsmt Exposure    1993 non-null   object
#  34  BsmtFin Type 1   1996 non-null   object
#  35  BsmtFin SF 1     2050 non-null   float64
#  36  BsmtFin Type 2   1995 non-null   object
#  37  BsmtFin SF 2     2050 non-null   float64
#  38  Bsmt Unf SF      2050 non-null   float64
#  39  Total Bsmt SF    2050 non-null   float64
#  40  Heating          2051 non-null   object
#  41  Heating QC       2051 non-null   object
#  42  Central Air      2051 non-null   object
#  43  Electrical       2051 non-null   object
#  44  1st Flr SF       2051 non-null   int64
#  45  2nd Flr SF       2051 non-null   int64
#  46  Low Qual Fin SF  2051 non-null   int64
#  47  Gr Liv Area      2051 non-null   int64
#  48  Bsmt Full Bath   2049 non-null   float64
#  49  Bsmt Half Bath   2049 non-null   float64
#  50  Full Bath        2051 non-null   int64
#  51  Half Bath        2051 non-null   int64
#  52  Bedroom AbvGr    2051 non-null   int64
#  53  Kitchen AbvGr    2051 non-null   int64
#  54  Kitchen Qual     2051 non-null   object
#  55  TotRms AbvGrd    2051 non-null   int64
#  56  Functional       2051 non-null   object
#  57  Fireplaces       2051 non-null   int64
#  58  Fireplace Qu     1051 non-null   object
#  59  Garage Type      1938 non-null   object
#  60  Garage Yr Blt    1937 non-null   float64
#  61  Garage Finish    1937 non-null   object
#  62  Garage Cars      2050 non-null   float64
#  63  Garage Area      2050 non-null   float64
#  64  Garage Qual      1937 non-null   object
#  65  Garage Cond      1937 non-null   object
#  66  Paved Drive      2051 non-null   object
#  67  Wood Deck SF     2051 non-null   int64
#  68  Open Porch SF    2051 non-null   int64
#  69  Enclosed Porch   2051 non-null   int64
#  70  3Ssn Porch       2051 non-null   int64
#  71  Screen Porch     2051 non-null   int64
#  72  Pool Area        2051 non-null   int64
#  73  Pool QC          9 non-null      object
#  74  Fence            400 non-null    object
#  75  Misc Feature     65 non-null     object
#  76  Misc Val         2051 non-null   int64
#  77  Mo Sold          2051 non-null   int64
#  78  Yr Sold          2051 non-null   int64
#  79  Sale Type        2051 non-null   object
#  80  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %%
train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# std        1.426271      1.104497    30.177889       21.036250    174.963129
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1953.500000     1964.500000      0.000000
# 50%        6.000000      5.000000  1974.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    161.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF   1st Flr SF  \
# count   2050.000000   2050.000000  2050.000000    2050.000000  2051.000000
# mean     442.300488     47.959024   567.728293    1057.987805  1164.488055
# std      461.204124    165.000901   444.954786     449.410704   396.446923
# min        0.000000      0.000000     0.000000       0.000000   334.000000
# 25%        0.000000      0.000000   220.000000     793.000000   879.500000
# 50%      368.000000      0.000000   474.500000     994.500000  1093.000000
# 75%      733.750000      0.000000   811.000000    1318.750000  1405.000000
# max     5644.000000   1474.000000  2336.000000    6110.000000  5095.000000
#
#         2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# count  2051.000000      2051.000000  2051.000000     2049.000000
# mean    329.329108         5.512921  1499.330083        0.427526
# std     425.671046        51.068870   500.447829        0.522673
# min       0.000000         0.000000   334.000000        0.000000
# 25%       0.000000         0.000000  1129.000000        0.000000
# 50%       0.000000         0.000000  1444.000000        0.000000
# 75%     692.500000         0.000000  1728.500000        1.000000
# max    1862.000000      1064.000000  5642.000000        3.000000
#
#        Bsmt Half Bath    Full Bath    Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# count     2049.000000  2051.000000  2051.000000    2051.000000    2051.000000
# mean         0.063446     1.577279     0.371039       2.843491       1.042906
# std          0.251705     0.549279     0.501043       0.826618       0.209790
# min          0.000000     0.000000     0.000000       0.000000       0.000000
# 25%          0.000000     1.000000     0.000000       2.000000       1.000000
# 50%          0.000000     2.000000     0.000000       3.000000       1.000000
# 75%          0.000000     2.000000     1.000000       3.000000       1.000000
# max          2.000000     4.000000     2.000000       8.000000       3.000000
#
#        TotRms AbvGrd   Fireplaces  Garage Yr Blt  Garage Cars  Garage Area  \
# count    2051.000000  2051.000000    1937.000000  2050.000000  2050.000000
# mean        6.435885     0.590931    1978.707796     1.776585   473.671707
# std         1.560225     0.638516      25.441094     0.764537   215.934561
# min         2.000000     0.000000    1895.000000     0.000000     0.000000
# 25%         5.000000     0.000000    1961.000000     1.000000   319.000000
# 50%         6.000000     1.000000    1980.000000     2.000000   480.000000
# 75%         7.000000     1.000000    2002.000000     2.000000   576.000000
# max        15.000000     4.000000    2207.000000     5.000000  1418.000000
#
#        Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count   2051.000000    2051.000000     2051.000000  2051.000000   2051.000000
# mean      93.833740      47.556802       22.571916     2.591419     16.511458
# std      128.549416      66.747241       59.845110    25.229615     57.374204
# min        0.000000       0.000000        0.000000     0.000000      0.000000
# 25%        0.000000       0.000000        0.000000     0.000000      0.000000
# 50%        0.000000      27.000000        0.000000     0.000000      0.000000
# 75%      168.000000      70.000000        0.000000     0.000000      0.000000
# max     1424.000000     547.000000      432.000000   508.000000    490.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice
# count  2051.000000   2051.000000  2051.000000  2051.000000    2051.000000
# mean      2.397855     51.574354     6.219893  2007.775719  181469.701609
# std      37.782570    573.393985     2.744736     1.312014   79258.659352
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129825.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  162500.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  611657.000000

# %% [markdown]
# - We can confirm that our dataframe is quite large, it has 81 variables and 2051 observations.
#
# - some of the variables have null values, the best thing to do is remove some and try to clean the others.

# %% [markdown]
# ## 2.1.  Data cleaning:

# %%
#TRAINING
#dropping some columns 

train.drop(['PID',"Alley",'Fireplace Qu','Pool QC','Fence','Misc Feature'],axis=1,inplace=True)

# %%
#TESTING
#dropping some columns 
test.drop(['PID',"Alley",'Fireplace Qu','Pool QC','Fence','Misc Feature'],axis=1,inplace=True)

# %%
#TRAINIG
# fill null values
train['Lot Frontage'].fillna(train['Lot Frontage'].mean(),inplace=True)

train['Mas Vnr Type'].fillna('None',inplace=True)
train['Mas Vnr Area'].fillna(0.0, inplace=True)

train['Bsmt Qual'].fillna("Na",inplace=True)
train['Bsmt Cond'].fillna('Na',inplace=True)
train['Bsmt Exposure'].fillna('Na',inplace=True)
train['BsmtFin Type 1'].fillna('Na',inplace=True)
train['BsmtFin Type 2'].fillna('Na',inplace=True)

train['BsmtFin SF 1'].fillna(0.0,inplace=True)
train['BsmtFin SF 2'].fillna(0.0,inplace=True)
train['Bsmt Unf SF'].fillna(0.0,inplace=True)
train['Total Bsmt SF'].fillna(0.0,inplace=True)


train['Bsmt Full Bath'].fillna(0.0,inplace=True)
train['Bsmt Half Bath'].fillna(0.0,inplace=True)

train['Garage Type'].fillna("Na",inplace=True)
train['Garage Yr Blt'].fillna(0.0,inplace=True)
train['Garage Finish'].fillna("Na",inplace=True)
train['Garage Cars'].fillna(0.0,inplace=True)
train['Garage Area'].fillna(0.0,inplace=True)
train['Garage Qual'].fillna("Na",inplace=True)
train['Garage Cond'].fillna("Na",inplace=True)

# %%
#TESTING
# fill null values
test['Lot Frontage'].fillna(test['Lot Frontage'].mean(),inplace=True)

test['Mas Vnr Type'].fillna('None',inplace=True)
test['Mas Vnr Area'].fillna(0.0, inplace=True)

test['Bsmt Qual'].fillna("Na",inplace=True)
test['Bsmt Cond'].fillna('Na',inplace=True)
test['Bsmt Exposure'].fillna('Na',inplace=True)
test['BsmtFin Type 1'].fillna('Na',inplace=True)
test['BsmtFin Type 2'].fillna('Na',inplace=True)

test['Electrical'].fillna('SBrkr',inplace=True)

test['Garage Type'].fillna("Na",inplace=True)
test['Garage Yr Blt'].fillna(0.0,inplace=True)
test['Garage Finish'].fillna("Na",inplace=True)
test['Garage Qual'].fillna("Na",inplace=True)
test['Garage Cond'].fillna("Na",inplace=True)

# %% [markdown]
# - I decided to drop some columns that have the majority of null values,and other null values fill the majority with no *None*, *0* or with the *mean*.

# %% [markdown]
# ## 3. Feature Visualizations:
# ---

# %%
#box plot target

sns.boxplot(data=train['SalePrice'],orient='h');
plt.savefig('../images/target_box.png')

# %%
#Mean of our target

train['SalePrice'].mean()
# Out:
# 181469.70160897123

# %%
# Histogram and distribution of the target

sns.displot(train['SalePrice'],bins=20,kde = True).set_axis_labels
plt.xlabel('Sale price $',fontdict={'fontsize':17});
plt.savefig('../images/target_histagram.png')

# %%
# plot of the Continuous features

sns.pairplot(data=train, 
             y_vars=['SalePrice'], 
             x_vars=['Gr Liv Area','Garage Area','Total Bsmt SF','1st Flr SF','Mas Vnr Area','Year Built', 'Year Remod/Add']);

# %%
# plot of the Categorical features

fig, axs = plt.subplots(2,3,figsize=(30, 12))

sns.boxplot(y=train['SalePrice'],x=train['Overall Qual'],ax=axs[0,0]).xaxis.label.set_size(20)


sns.boxplot(y=train['SalePrice'],x=train['Exter Qual'],ax=axs[0,1]).xaxis.label.set_size(20)


sns.boxplot(y=train['SalePrice'],x=train['Garage Cars'],ax=axs[0,2]).xaxis.label.set_size(20)


sns.boxplot(y=train['SalePrice'],x=train['Kitchen Qual'],ax=axs[1,0]).xaxis.label.set_size(20)


sns.boxplot(y=train['SalePrice'],x=train['Bsmt Qual'],ax=axs[1,1]).xaxis.label.set_size(20)


sns.boxplot(y=train['SalePrice'],x=train['Full Bath'],ax=axs[1,2]).xaxis.label.set_size(20)


plt.savefig('../images/cat_box.png')
plt.show()

# %% [markdown]
# - Analyzing the graphs of our target (*saleprice*). We can deduce that in the box graph our target has some outliers (for now we are not interested), we can also see where the majority of values accumulate and we will have an idea of what the average of our target would be.
# - In the graph of the histogram we see that it has an almost normal distribution, but it has a small *positive skew*.
# - Some of the *features* have some outliers that we are going to try to fix, so that our model performs better.

# %% [markdown]
# ## 3.1 Removing Outliers

# %%
train.drop(index=train[train['Total Bsmt SF']>5000].index,inplace=True)
train.drop(index=train[(train['Overall Qual']==8)&(train['SalePrice']>500000)].index,inplace=True)
train.drop(index=train[(train['Overall Qual']==6)&(train['SalePrice']>400000)].index,inplace=True)
train.drop(index=train[(train['Overall Qual']==9)&(train['SalePrice']>550000)].index,inplace=True)
train.drop(index=train[(train['Overall Qual']==4)&(train['SalePrice']>200000)].index,inplace=True)
train.drop(index=train[train['Garage Area']==0].index,inplace=True)


test.drop(index=test[test['Total Bsmt SF']>5000].index,inplace=True)
test.drop(index=test[test['Garage Area']==0].index,inplace=True)

# %% [markdown]
# - now our features look much better after dropping some of the *outliers*, and now we can proceed to implement our models

# %% [markdown]
# ## 4. Data Analysis:
# ---

# %% [markdown]
# #### Prices of the house by neighborhood

# %%
#graphic of the neighborhood 

plt.figure(figsize=(10, 9))

train.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=False).plot(kind='bar');
plt.title('Most expensive neighborhoods')
plt.savefig('../images/bar_neb.png')

# %%
# Check how many house are in the neighborhood 

train[(train['Neighborhood']=='NridgHt')].value_counts().sum()
# Out:
# 120

# %%
#mean 
train.loc[train.Neighborhood=='NridgHt','SalePrice'].mean()
# Out:
# 318256.9583333333

# %%
#max price
train.loc[train.Neighborhood=='NridgHt','SalePrice'].max()
# Out:
# 555000

# %%
#grafic of the NridgHt 
plt.figure(figsize=(10, 9))

train.loc[train.Neighborhood=='NridgHt','SalePrice'].plot.line(color='green');
plt.title('Price of Northridge Heights houses',fontdict={'fontsize':17})
plt.ylabel('Sale price $',fontdict={'fontsize':17});
plt.savefig('../images/Neighbor_price.png')

# %%
#top 10 of the most expensive houses in NridgHt

train[(train['Neighborhood']=='NridgHt')].sort_values(by='SalePrice',ascending=False).head(10)
# Out:
#         Id  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 1164   424           20        RL         105.0     15431   Pave       Reg
# 623    457           20        RL         100.0     14836   Pave       IR1
# 800   1702           20        RL          59.0     17169   Pave       IR2
# 1227    47           20        RL         110.0     14300   Pave       Reg
# 1700   423           60        RL         104.0     13518   Pave       Reg
# 41    2383           20        RL         107.0     13891   Pave       Reg
# 332   1060           60        RL          96.0     12539   Pave       Reg
# 529    432           60        RL          97.0     13478   Pave       IR1
# 986   1694           20        RL         105.0     15431   Pave       Reg
# 509   1054           60        RL          67.0     14948   Pave       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1164          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 623           HLS    AllPub     Inside        Mod      NridgHt        Norm
# 800           Lvl    AllPub    CulDSac        Gtl      NridgHt        Norm
# 1227          HLS    AllPub     Inside        Mod      NridgHt        Norm
# 1700          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 41            Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 332           Lvl    AllPub     Inside        Gtl      NridgHt        PosN
# 529           Lvl    AllPub     Corner        Gtl      NridgHt        Norm
# 986           Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 509           Lvl    AllPub     Inside        Gtl      NridgHt        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 1164        Norm      1Fam      1Story            10             5
# 623         Norm      1Fam      1Story            10             5
# 800         Norm      1Fam      1Story            10             5
# 1227        Norm      1Fam      1Story             9             5
# 1700        Norm      1Fam      2Story             9             5
# 41          Norm      1Fam      1Story            10             5
# 332         Norm      1Fam      2Story            10             5
# 529         Norm      1Fam      2Story            10             5
# 986         Norm      1Fam      1Story            10             5
# 509         Norm      1Fam      2Story             9             5
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 1164        2008            2008        Hip   CompShg      VinylSd
# 623         2004            2005        Hip   CompShg      CemntBd
# 800         2007            2007        Hip   CompShg      CemntBd
# 1227        2003            2004        Hip   CompShg      VinylSd
# 1700        2008            2009        Hip   CompShg      VinylSd
# 41          2006            2006      Gable   CompShg      VinylSd
# 332         2005            2006        Hip   CompShg      CemntBd
# 529         2008            2008      Gable   CompShg      CemntBd
# 986         2005            2006        Hip   CompShg      VinylSd
# 509         2008            2008        Hip   CompShg      VinylSd
#
#      Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 1164      VinylSd        Stone         200.0         Ex         TA      PConc
# 623       CmentBd        Stone         730.0         Ex         TA      PConc
# 800       CmentBd      BrkFace         970.0         Ex         TA      PConc
# 1227      VinylSd      BrkFace        1095.0         Ex         TA      PConc
# 1700      VinylSd        Stone         860.0         Ex         TA      PConc
# 41        VinylSd         None           0.0         Ex         TA      PConc
# 332       CmentBd      BrkFace         468.0         Ex         TA      PConc
# 529       CmentBd        Stone         420.0         Ex         TA      PConc
# 986       VinylSd      BrkFace         400.0         Ex         TA      PConc
# 509       VinylSd        Stone         268.0         Ex         TA      PConc
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1164        Ex        TA            Gd            GLQ        1767.0
# 623         Ex        TA            Gd            GLQ        2146.0
# 800         Ex        TA            Av            GLQ        1684.0
# 1227        Ex        TA            Gd            GLQ        1373.0
# 1700        Ex        TA            No            Unf           0.0
# 41          Ex        Gd            Gd            GLQ        1386.0
# 332         Ex        TA            Gd            GLQ        1082.0
# 529         Ex        TA            Gd            GLQ        1338.0
# 986         Ex        TA            Gd            GLQ        1430.0
# 509         Ex        TA            Av            GLQ        1330.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 1164            ALQ         539.0        788.0         3094.0    GasA
# 623             Unf           0.0        346.0         2492.0    GasA
# 800             Unf           0.0        636.0         2320.0    GasA
# 1227            Unf           0.0       1473.0         2846.0    GasA
# 1700            Unf           0.0       1926.0         1926.0    GasA
# 41              Unf           0.0        690.0         2076.0    GasA
# 332             Unf           0.0        538.0         1620.0    GasA
# 529             Unf           0.0        384.0         1722.0    GasA
# 986             Unf           0.0        564.0         1994.0    GasA
# 509             Unf           0.0        122.0         1452.0    GasA
#
#      Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 1164         Ex           Y      SBrkr        2402           0
# 623          Ex           Y      SBrkr        2492           0
# 800          Ex           Y      SBrkr        2290           0
# 1227         Ex           Y      SBrkr        2696           0
# 1700         Ex           Y      SBrkr        1966        1174
# 41           Ex           Y      SBrkr        2076           0
# 332          Ex           Y      SBrkr        1632        1158
# 529          Ex           Y      SBrkr        1728         568
# 986          Ex           Y      SBrkr        2046           0
# 509          Ex           Y      SBrkr        1476        1237
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 1164                0         2402             1.0             0.0          2
# 623                 0         2492             1.0             0.0          2
# 800                 0         2290             2.0             0.0          2
# 1227                0         2696             1.0             0.0          2
# 1700                0         3140             0.0             0.0          3
# 41                  0         2076             1.0             0.0          2
# 332                 0         2790             1.0             0.0          2
# 529                 0         2296             1.0             0.0          2
# 986                 0         2046             1.0             0.0          2
# 509                 0         2713             1.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 1164          0              2              1           Ex             10
# 623           1              2              1           Ex              8
# 800           1              2              1           Ex              7
# 1227          1              3              1           Ex             10
# 1700          1              4              1           Ex             11
# 41            1              2              1           Ex              7
# 332           1              4              1           Ex             10
# 529           1              3              1           Ex             10
# 986           1              2              1           Ex              7
# 509           1              3              1           Ex             11
#
#      Functional  Fireplaces Garage Type  Garage Yr Blt Garage Finish  \
# 1164        Typ           2      Attchd         2008.0           Fin
# 623         Typ           1      Attchd         2004.0           Fin
# 800         Typ           1      Attchd         2007.0           Fin
# 1227        Typ           2      Attchd         2003.0           Fin
# 1700        Typ           2     BuiltIn         2009.0           Fin
# 41          Typ           1      Attchd         2006.0           Fin
# 332         Typ           1     BuiltIn         2005.0           Fin
# 529         Typ           1     BuiltIn         2008.0           RFn
# 986         Typ           2      Attchd         2005.0           Fin
# 509         Typ           1      Attchd         2008.0           Fin
#
#       Garage Cars  Garage Area Garage Qual Garage Cond Paved Drive  \
# 1164          3.0        672.0          TA          TA           Y
# 623           3.0        949.0          TA          TA           Y
# 800           3.0       1174.0          TA          TA           Y
# 1227          3.0        958.0          TA          TA           Y
# 1700          3.0        820.0          TA          TA           Y
# 41            3.0        850.0          TA          TA           Y
# 332           4.0       1150.0          TA          TA           Y
# 529           3.0        842.0          TA          TA           Y
# 986           3.0        878.0          TA          TA           Y
# 509           3.0        858.0          TA          TA           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# 1164             0             72               0           0           170
# 623            226            235               0           0             0
# 800            192             30               0           0             0
# 1227           220            150               0           0             0
# 1700           144             78               0           0             0
# 41             216            229               0           0             0
# 332             30            200               0           0           192
# 529            382            274               0           0             0
# 986            188             65               0           0           175
# 509            126             66               0           0             0
#
#       Pool Area  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 1164          0         0        4     2009       WD      555000
# 623           0         0        2     2009       WD      552000
# 800           0         0        8     2007       New     500067
# 1227          0         0        6     2010       WD      500000
# 1700          0         0        7     2009       New     485000
# 41            0         0        9     2006       New     465000
# 332           0         0        6     2008       WD      460000
# 529           0         0        6     2009     ConLI     451950
# 986           0         0        8     2007       WD      450000
# 509           0         0       11     2008       New     446261

# %% [markdown]
# - As we can see in the graph, we have the neighborhoods with the average of the prices and we see that *Northridge Heights* is the one with the highest prices in the market.
# - Also we see that this neighborhood has 120 houses and we can see the top 10 in detail which characteristics of these houses are.
# - the average of a house is $318256.9
# - The highest price is $555000

# %% [markdown]
# ## 5. Feature engineering:
# ---

# %%
# Transformation of type
#I want to do it with a for loop

cols = [
    'MS Zoning', 'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 
    'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
    'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type','Mas Vnr Area', 'Exter Qual', 
    'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1',
        'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Kitchen Qual',
    'Functional', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive',
    'Sale Type']

train[cols] = train[cols].astype('category')
test[cols] = test[cols].astype('category')

# %%
#Encode categorical features

#instance encoder
encoder = OrdinalEncoder() 
encoder1 = OrdinalEncoder() 

encoder.fit(train[cols])
encoder1.fit(test[cols])

train[cols] = encoder.transform(train[cols])
test[cols] = encoder1.transform(test[cols])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1926 entries, 0 to 2050
# Data columns (total 75 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               1926 non-null   int64
#  1   MS SubClass      1926 non-null   int64
#  2   MS Zoning        1926 non-null   float64
#  3   Lot Frontage     1926 non-null   float64
#  4   Lot Area         1926 non-null   int64
#  5   Street           1926 non-null   float64
#  6   Lot Shape        1926 non-null   float64
#  7   Land Contour     1926 non-null   float64
#  8   Utilities        1926 non-null   float64
#  9   Lot Config       1926 non-null   float64
#  10  Land Slope       1926 non-null   float64
#  11  Neighborhood     1926 non-null   float64
#  12  Condition 1      1926 non-null   float64
#  13  Condition 2      1926 non-null   float64
#  14  Bldg Type        1926 non-null   float64
#  15  House Style      1926 non-null   float64
#  16  Overall Qual     1926 non-null   int64
#  17  Overall Cond     1926 non-null   int64
#  18  Year Built       1926 non-null   int64
#  19  Year Remod/Add   1926 non-null   int64
#  20  Roof Style       1926 non-null   float64
#  21  Roof Matl        1926 non-null   float64
#  22  Exterior 1st     1926 non-null   float64
#  23  Exterior 2nd     1926 non-null   float64
#  24  Mas Vnr Type     1926 non-null   float64
#  25  Mas Vnr Area     1926 non-null   float64
#  26  Exter Qual       1926 non-null   float64
#  27  Exter Cond       1926 non-null   float64
#  28  Foundation       1926 non-null   float64
#  29  Bsmt Qual        1926 non-null   float64
#  30  Bsmt Cond        1926 non-null   float64
#  31  Bsmt Exposure    1926 non-null   float64
#  32  BsmtFin Type 1   1926 non-null   float64
#  33  BsmtFin SF 1     1926 non-null   float64
#  34  BsmtFin Type 2   1926 non-null   float64
#  35  BsmtFin SF 2     1926 non-null   float64
#  36  Bsmt Unf SF      1926 non-null   float64
#  37  Total Bsmt SF    1926 non-null   float64
#  38  Heating          1926 non-null   float64
#  39  Heating QC       1926 non-null   float64
#  40  Central Air      1926 non-null   float64
#  41  Electrical       1926 non-null   float64
#  42  1st Flr SF       1926 non-null   int64
#  43  2nd Flr SF       1926 non-null   int64
#  44  Low Qual Fin SF  1926 non-null   int64
#  45  Gr Liv Area      1926 non-null   int64
#  46  Bsmt Full Bath   1926 non-null   float64
#  47  Bsmt Half Bath   1926 non-null   float64
#  48  Full Bath        1926 non-null   int64
#  49  Half Bath        1926 non-null   int64
#  50  Bedroom AbvGr    1926 non-null   int64
#  51  Kitchen AbvGr    1926 non-null   int64
#  52  Kitchen Qual     1926 non-null   float64
#  53  TotRms AbvGrd    1926 non-null   int64
#  54  Functional       1926 non-null   float64
#  55  Fireplaces       1926 non-null   int64
#  56  Garage Type      1926 non-null   float64
#  57  Garage Yr Blt    1926 non-null   float64
#  58  Garage Finish    1926 non-null   float64
#  59  Garage Cars      1926 non-null   float64
#  60  Garage Area      1926 non-null   float64
#  61  Garage Qual      1926 non-null   float64
#  62  Garage Cond      1926 non-null   float64
#  63  Paved Drive      1926 non-null   float64
#  64  Wood Deck SF     1926 non-null   int64
#  65  Open Porch SF    1926 non-null   int64
#  66  Enclosed Porch   1926 non-null   int64
#  67  3Ssn Porch       1926 non-null   int64
#  68  Screen Porch     1926 non-null   int64
#  69  Pool Area        1926 non-null   int64
#  70  Misc Val         1926 non-null   int64
#  71  Mo Sold          1926 non-null   int64
#  72  Yr Sold          1926 non-null   int64
#  73  Sale Type        1926 non-null   float64
#  74  SalePrice        1926 non-null   int64
# dtypes: float64(48), int64(27)
# memory usage: 1.1 MB

# %% [markdown]
# - Using the "OrdinalEncoder" library we can make the transformation of the categorical variables to be able to use them in our future model.
#
# - now our dataframe is clean and all variables are numeric.

# %% [markdown]
# ## 6. Feature selection and correlation graphic:
# ---

# %%
#target variable

y=train['SalePrice']

# %% [markdown]
# #### two ways selecting features for X

# %%
#https://towardsdatascience.com/feature-selection-techniques-in-machine-learning-with-python-f24e7da3f36e

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=f_regression, k=10)
fit = bestfeatures.fit(train,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(train.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 21 best features
# Out:
#          Features        Score
# 16   Overall Qual  3683.154808
# 45    Gr Liv Area  2057.220936
# 26     Exter Qual  1691.065662
# 52   Kitchen Qual  1477.630029
# 37  Total Bsmt SF  1459.204005
# 59    Garage Cars  1415.453189
# 60    Garage Area  1376.553950
# 42     1st Flr SF  1323.096467
# 29      Bsmt Qual  1060.148354
# 18     Year Built   936.582333

# %%
# using the correlation of price 
matrix = train.corr()
values = matrix["SalePrice"].sort_values(ascending=False)

top_10 = values[:10]
bottom_10 = values[-10:]

print(f"top_10\n{top_10}")
print(f"bottom_10\n{bottom_10}")
# Out:
# top_10
# SalePrice         1.000000
# Overall Qual      0.810473
# Gr Liv Area       0.718840
# Total Bsmt SF     0.656741
# Garage Cars       0.651044
# Garage Area       0.645808
# 1st Flr SF        0.638334
# Year Built        0.572197
# Year Remod/Add    0.553909
# Garage Yr Blt     0.542259
# Name: SalePrice, dtype: float64
# bottom_10
# BsmtFin Type 1   -0.131013
# MS Zoning        -0.143049
# Lot Shape        -0.289761
# Bsmt Exposure    -0.326824
# Garage Type      -0.391175
# Heating QC       -0.437016
# Garage Finish    -0.535986
# Bsmt Qual        -0.596037
# Kitchen Qual     -0.659082
# Exter Qual       -0.683947
# Name: SalePrice, dtype: float64

# %%
#feature variables
features=['Overall Qual','Gr Liv Area','Exter Qual','Garage Area','Kitchen Qual',
         'Total Bsmt SF','1st Flr SF','Bsmt Qual','Year Built','Year Remod/Add','Full Bath',
         'Mas Vnr Area']
X=train[features]

# %%
#heat map to find the correlation 

heat=train[['Overall Qual','Gr Liv Area','Exter Qual','Garage Area','Kitchen Qual',
         'Total Bsmt SF','1st Flr SF','Bsmt Qual','Year Built','Year Remod/Add','Full Bath',
         'Mas Vnr Area','SalePrice']]

corr =heat.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True


plt.figure(figsize=(10, 9))
sns.heatmap(heat.corr(),vmin=-1,
    vmax=1,
    cmap=None,
    mask=mask,
    center=None,
    robust=False,
    annot=True,
    annot_kws=None,
    linecolor='white',
    square=True,);

plt.savefig('../images/corr.png')

# %%
#Grafic of correlation of independent variables with the dependent Variable 
#I took a piece of the code from (https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e)

plt.figure(figsize=(10, 9))
sns.heatmap(heat.corr()
            [['SalePrice']].sort_values(
                by='SalePrice', ascending=False),
            vmin=-1, 
            vmax=1, 
            annot=True, 
            cmap=None)
plt.savefig('../images/corr_price.png')

# %% [markdown]
# - we assign the variable value of * saleprice * as our target.
#
# - With the help of the *sklearn* library we can use the *SelectKbest * module to select the 10 best features. We can also use the correlation table to see which features have the highest correlation.
#
# - I have chosen the 12 best features that had high and low correlation
#
# - At the end we can see the correlation that have the 10 best features, we see the *Overall Qual* has the highest correlation.

# %% [markdown]
# ## 7. Creating models:
# ---

# %% [markdown]
# - ### Linear regression model: Statsmodels.OLS model
# ---

# %%
#model with statsmodels and see the table 

X_const = sm.add_constant(X)
lkd =sm.OLS(y,X_const).fit()
lkd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     1036.
# Date:                Fri, 03 Dec 2021   Prob (F-statistic):               0.00
# Time:                        20:54:44   Log-Likelihood:                -22434.
# No. Observations:                1926   AIC:                         4.489e+04
# Df Residuals:                    1913   BIC:                         4.497e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -7.682e+05   9.23e+04     -8.326      0.000   -9.49e+05   -5.87e+05
# Overall Qual    1.279e+04    809.121     15.811      0.000    1.12e+04    1.44e+04
# Gr Liv Area       55.5364      2.105     26.383      0.000      51.408      59.665
# Exter Qual     -9477.4650   1412.351     -6.710      0.000   -1.22e+04   -6707.555
# Garage Area       36.8690      4.543      8.115      0.000      27.958      45.780
# Kitchen Qual   -1.071e+04   1098.588     -9.751      0.000   -1.29e+04   -8558.059
# Total Bsmt SF     27.6535      2.678     10.325      0.000      22.401      32.906
# 1st Flr SF        13.4857      2.981      4.523      0.000       7.638      19.333
# Bsmt Qual      -2769.2239    534.183     -5.184      0.000   -3816.866   -1721.582
# Year Built       187.1695     35.472      5.277      0.000     117.602     256.737
# Year Remod/Add   218.5450     44.731      4.886      0.000     130.819     306.271
# Full Bath      -1.421e+04   1709.110     -8.312      0.000   -1.76e+04   -1.09e+04
# Mas Vnr Area      48.6996      7.637      6.376      0.000      33.721      63.678
# ==============================================================================
# Omnibus:                      171.031   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              899.063
# Skew:                           0.228   Prob(JB):                    5.90e-196
# Kurtosis:                       6.316   Cond. No.                     5.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# - Using the library of *statsmodels*, we can create a model using our variables *X* and *y*.
# - this table bring us a very Valuable information about target. we can see that our _R-squared_ is _0.820_, that means that 82% of the variance can be explain for a depend variable.
# - we can see the _coefficients_ of our features and the _p_value_ that Describe the relation that the features have with the target.
# - how we see in the model the _p_value_ is lower than 5% so we can reject the null hypotesis.

# %% [markdown]
# # Frist version for Kaggle

# %% [markdown]
# - ### Linear regression model: Sklearn model
# ---

# %% [markdown]
# #### Model Prep: Train/test split and Scale

# %%
#split our data

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.7, random_state=42)

# %%
#scale our data

ss = StandardScaler()

X_train= ss.fit_transform(X_train) 

X_test= ss.transform(X_test)

# %% [markdown]
# #### Model Prep: Instantiate our model

# %%
#Instantiate our model.
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Cross validation

# %%
# Training Testing Cross Val

print(f'Cross validation training: {cross_val_score(linreg, X_train, y_train).mean()}')
print(f'Cross validation test: {cross_val_score(linreg, X_test, y_test).mean()}')
# Out:
# Cross validation training: 0.8661376310377902
# Cross validation test: 0.8451069330114634

# %% [markdown]
# #### Intercept and coefficient

# %%
print(f'Intercept: {linreg.intercept_}')
pd.DataFrame(list(zip(X, linreg.coef_)),columns=['Features','Coefficient '])
# Out:
# Intercept: 185977.51261127603
#           Features  Coefficient
# 0     Overall Qual  16772.329959
# 1      Gr Liv Area  26293.195770
# 2       Exter Qual  -6536.097731
# 3      Garage Area   6747.437029
# 4     Kitchen Qual -10228.959810
# 5    Total Bsmt SF  12135.374337
# 6       1st Flr SF   4706.861250
# 7        Bsmt Qual  -4906.144584
# 8       Year Built   5420.717234
# 9   Year Remod/Add   4565.492265
# 10       Full Bath  -6763.885734
# 11    Mas Vnr Area   4774.167032

# %% [markdown]
# #### Prediction Metrics and Residuals

# %%
#create predictions
train_preds = linreg.predict(X_train)
test_preds = linreg.predict(X_test)

# %%
# Training score
print(f'R2 score training: {linreg.score(X_train, y_train)}')
print(f'R2 score test: {linreg.score(X_test, y_test)}')
# Out:
# R2 score training: 0.8691634156477879
# R2 score test: 0.8585891939305877

# %%
# Via sklearn.metrics
print(f'MAE training: {metrics.mean_absolute_error(y_train, train_preds)}')
print(f'MAE testing: {metrics.mean_absolute_error(y_test, test_preds)}')
# Out:
# MAE training: 20499.962536219304
# MAE testing: 20700.784052849107

# %%
# MSE using sklearn
print(f'MSE training: {metrics.mean_squared_error(y_train, train_preds)}')
print(f'MSE testing: {metrics.mean_squared_error(y_test, test_preds)}')
# Out:
# MSE training: 778755012.7439287
# MSE testing: 744281730.3698186

# %%
# RMSE - without using NumPy
# squared=False gives us the square root
print(f'RMSE training: {metrics.mean_squared_error(y_train, train_preds, squared = False)}')
print(f'RMSE testing: {metrics.mean_squared_error(y_test, test_preds, squared = False)}')
# Out:
# RMSE training: 27906.182339114905
# RMSE testing: 27281.52727341009

# %%
# calculate residuals
residuals = y_train - train_preds
# mean of residuals
residuals.mean()
# Out:
# -2.3609079083411204e-11

# %%
plt.scatter(y_train, train_preds);
plt.savefig('../images/pred1.png')

# %% [markdown]
# - the performance of this model is ok, 86.91% of the variance/variability in our y salesprice is explained by the features in our model.
# - Our model is just 27906.1 off we can see in our RMSE metrics

# %% [markdown]
# ### Ridge and Lasso:

# %% [markdown]
# #### Ridge

# %%
#Instantiate
ridge_model = Ridge(alpha=10)

#Fit
ridge_model.fit(X_train, y_train)

# Evaluate model using R2.
print(f"Ridge Training R-Squared: {ridge_model.score(X_train, y_train)}")
print(f"Ridge Testing R-Squared: {ridge_model.score(X_test, y_test)}")
# Out:
# Ridge Training R-Squared: 0.8691441364506721
# Ridge Testing R-Squared: 0.8584757169151975

# %% [markdown]
# #### Lasso

# %%
#Instantiate
lasso_model =Lasso(alpha=5)

#Fit
lasso_model.fit(X_train, y_train)

# Evaluate model using R2.
print(f"lasso Training R-Squared: {lasso_model.score(X_train, y_train)}")
print(f"Lasso Testing R-Squared: {lasso_model.score(X_test, y_test)}")
# Out:
# lasso Training R-Squared: 0.869163375332224
# Lasso Testing R-Squared: 0.8585826694512284

# %% [markdown]
# - Trying to improve our model we are going to use some regulations like Ridge and Lasso.
# - For Ridge we are going to put a value for alpha of 10 and for Lasso a value of 5.
# - As we can see, there is not much difference between the results.

# %% [markdown]
# # Second version for Kaggle

# %% [markdown]
# - ### Linear regression model: Sklearn,Polynomial features and Ridge
# ---

# %%
# Instantiate our PolynomialFeatures object to create all two-way terms.
poly = PolynomialFeatures(include_bias = False, degree=2, interaction_only=False)

# Fit and transform our X data.
X_overfit = poly.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_overfit, y, test_size=.7, random_state=42)

# %%
# Scale our data.
# Relabeling scaled data as "Z" is common.
sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %%
ols = LinearRegression()
ols.fit(Z_train, y_train)
# Out:
# LinearRegression()

# %%
#Instantiate
ridge_model = Ridge(alpha=10)

#Fit
ridge_model.fit(Z_train, y_train)

# Evaluate model using R2.
print(f"Ridge Training R-Squared: {ridge_model.score(Z_train, y_train)}")
print(f"Ridge Testing R-Squared: {ridge_model.score(Z_test, y_test)}")
# Out:
# Ridge Training R-Squared: 0.9122874374761231
# Ridge Testing R-Squared: 0.8834821737191104

# %%
#create predictions
train_predic = ols.predict(Z_train)
test_predic = ols.predict(Z_test)

# %%
# calculate residuals
resids = y_train - train_predic
# mean of residuals
resids.mean()
# Out:
# -4.3882725298714595e-11

# %%
# Training score
print(f'R2 score training: {ols.score(Z_train, y_train)}')
print(f'R2 score test: {ols.score(Z_test, y_test)}')
# Out:
# R2 score training: 0.923765574104372
# R2 score test: 0.8586968203065963

# %%
# Via sklearn.metrics
print(f'MAE training: {metrics.mean_absolute_error(y_train, train_predic)}')
print(f'MAE testing: {metrics.mean_absolute_error(y_test, test_predic)}')
# Out:
# MAE training: 15627.458460309716
# MAE testing: 19882.87949746396

# %%
# MSE using sklearn
print(f'MSE training: {metrics.mean_squared_error(y_train, train_predic)}')
print(f'MSE testing: {metrics.mean_squared_error(y_test, test_predic)}')
# Out:
# MSE training: 463566150.093549
# MSE testing: 792551156.4219079

# %%
# RMSE - without using NumPy
# squared=False gives us the square root
print(f'RMSE training: {metrics.mean_squared_error(y_train, train_predic, squared = False)}')
print(f'RMSE testing: {metrics.mean_squared_error(y_test, test_predic, squared = False)}')
# Out:
# RMSE training: 21530.586385269424
# RMSE testing: 28152.28510124725

# %%
plt.scatter(y_train, train_predic);
plt.savefig('../images/pred2.png')

# %% [markdown]
# As we can see with this model, our value for R2 has increased to 91.2%. This is because we have used the PolynomialFeatures function to increase the amount of our features and then we have done a RIDGE regulation with an alpha of 10, this has increased our values.As we can see with this model, our value for R2 has increased to 91.2%. This is because we have used the PolynomialFeatures function to increase the amount of our features and then we have done a RIDGE regulation with an alpha of 10, this has increased our values.- As we can see with this model, our value for R2 has increased to 91.2%. This is because we have used the *PolynomialFeatures* function to increase the amount of our features and then we have done a RIDGE regulation with an alpha of 10, this has increased our values.

# %% [markdown]
# ## Kaggle submission
# ---

# %% [markdown]
# # First version

# %%
tra = ss.fit_transform(test[features])
kaggle_preds = linreg.predict(tra)

# %%
test['saleprice'] = kaggle_preds

# %%
# Checking the data
test[['Id','saleprice']]
# Out:
#        Id      saleprice
# 0    2658  189486.276966
# 1    2718  216144.676228
# 2    2414  193809.695965
# 3    1989  128492.223895
# 4     625  186935.316396
# ..    ...            ...
# 873  1662  173678.840515
# 874  1234  222940.850421
# 875  1373  127791.474452
# 876  1672   98821.564484
# 877  1939  105576.507861
#
# [834 rows x 2 columns]

# %% [markdown]
# # Second version

# %%
# Using our transformer from above
kaggle_poly = poly.transform(test[features])
kag = sc.fit_transform(kaggle_poly)

# %%
# Making predictions
kaggle_preds = ols.predict(kag)

# %%
# Assigning to dataframe
test['saleprice'] = kaggle_preds

# %%
# Checking the data
test[['Id','saleprice']]
# Out:
#        Id      saleprice
# 0    2658  185078.423975
# 1    2718  160855.293801
# 2    2414  170526.724576
# 3    1989  129105.146048
# 4     625  181474.992615
# ..    ...            ...
# 873  1662  188900.076563
# 874  1234  201283.447539
# 875  1373  143296.299346
# 876  1672  127920.918383
# 877  1939  132876.928246
#
# [834 rows x 2 columns]

# %%
# Exporting 
test[['Id','saleprice']].to_csv('../datasets/kaggle_sub.csv', index=False)

# %% [markdown]
# ## Conclusions:
# ---

# %% [markdown]
# In conclusion,with the amount of data that provided to us, we can conclude that several *features* may influence the value of a property. With the help of SKLEARN we can see what are the best features for our model, a few of this features are *Overall Qual*,*Gr Liv Area*,*Exter Qual*, for the proposes of this project I decided to take the top 12. Using the graphs we can analyze several factors such as the distribution that the price represents. With the help of these graphs we can also answer our question about the price of houses by neighborhood. It was interesting to discover that *Northridge Heights* was the neighborhood with the highest price margin.
# One factor to consider was that we have done a cleaning of the null values in the best way possible to interpret(for me).
# In this project I have created several regression models to see how well they preform. My last model has a pretty good score to compere with the others.R2 has increased to 91.2%. This is because we have used the *PolynomialFeatures* function to increase the amount of our features and then we have done a RIDGE regulation with an alpha of 10, this has increased our values.
# At the end I am happy with the last model because I improve the score Significantly.
